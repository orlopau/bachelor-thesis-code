# %%
import wandb
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import runs_store as rs

plt.rcParams['figure.dpi'] = 100

# %%
runs = {
    "baseline": rs.load_runs(f"../data/runs/orlopau/gpu2/batch_baseline.pickle"),
}

for k,v in runs.items():
    runs[k] = rs.reduce_runs(v)

fig, ax = plt.subplots()
ax.grid()
ax.set_ylabel("Test accuracy")
ax.set_xlabel("Batch size")

ax.plot(runs["baseline"]["batch_size"], runs["baseline"]["acc_test_act_min"], label="No scaling")

ax.legend()
